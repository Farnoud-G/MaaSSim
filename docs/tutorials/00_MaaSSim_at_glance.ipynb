# %%
import os, sys # add MaaSSim to path (not needed if MaaSSim is already in path)
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)
import MaaSSim

# %%
#!pip install MaaSSim
import MaaSSim.utils
import logging
from dotmap import DotMap
import MaaSSim.simulators
from MaaSSim.data_structures import structures as inData

# %%
sim = MaaSSim.simulators.simulate(config = 'glance.json')  # run the simulation from a given configuration
sim.runs[0].trips  # access the results
params = MaaSSim.utils.get_config('glance.json')  # load configuration
params.city = "Nootdorp, Netherlands" # modify it
inData = MaaSSim.utils.load_G(inData,params)  # load the graph for a different city
sim_1 = MaaSSim.simulators.simulate(params=params) # run the simulation
params.nP = 5 # change number of travellers
inData = MaaSSim.utils.prep_supply_and_demand(inData, params)  # regenerate supply and demand
sim_2 = MaaSSim.simulators.simulate(inData=inData,params=params) # run the second simulation
print('Total waiting time: {}s in first simulation and {}s in the second.'.format(sim_1.res[0].pax_exp['WAIT'].sum(),
      sim_2.res[0].pax_exp['WAIT'].sum()))  # compare some results
space =  dict(nP=[5,10,20], nV = [5,10]) # define search space of supply and demand levels
MaaSSim.simulators.simulate_parallel(inData=inData, params=params, search_space = space, logger_level = logging.WARNING) # run parallel experiments
res = MaaSSim.utils.collect_results(params.paths.dumps) # collect results from  parallel experiments

def my_function(**kwargs): # user defined function to represent agent decisions
    veh = kwargs.get('veh', None)  # input from simulation
    sim = veh.sim  # access to simulation object
    if len(sim.runs) > 0:
        if sim.res[last_run].veh_exp.loc[veh.id].nRIDES > 3:
            return False # if I had more than 3 rides yesterday I stay
        else:
            return True # otherwise I leave
    else:
        return True # I do not leave on first day
        
sim = MaaSSim.simulators.simulate(inData=inData,params=params, f_driver_out = my_function, logger_level = logging.INFO) # simulate with my user defined function
# Out:
# 17-07-24 16:02:17-WARNING-Setting up 4h simulation at 2024-07-17 14:36:44 for 2 vehicles and 5 passengers in Nootdorp, Netherlands
# 17-07-24 16:02:17-INFO--------------------	Starting simulation	-------------------
# 17-07-24 16:02:17-INFO-pax    0  got to dest at                           2024-07-17 14:43:21
# 17-07-24 16:02:17-INFO-pax    1  got to dest at                           2024-07-17 14:57:04
# 17-07-24 16:02:17-INFO-pax    2  got to dest at                           2024-07-17 17:38:46
# 17-07-24 16:02:17-INFO-pax    3  got to dest at                           2024-07-17 17:48:49
# 17-07-24 16:02:17-INFO-pax    4  got to dest at                           2024-07-17 17:50:11
# 17-07-24 16:02:17-INFO-veh    2  quitted shift                            2024-07-17 20:36:43
# 17-07-24 16:02:17-INFO-veh    1  quitted shift                            2024-07-17 20:36:43
# 17-07-24 16:02:17-INFO--------------------	Simulation over		-------------------
# 17-07-24 16:02:17-INFO-queue of requests 0
# 17-07-24 16:02:17-WARNING-simulation time 0.1 s
# 17-07-24 16:02:17-WARNING-assertion tests for simulation results - passed
# 17-07-24 16:02:17-WARNING-Setting up 4h simulation at 2024-07-17 14:07:32 for 2 vehicles and 5 passengers in Nootdorp, Netherlands
# 17-07-24 16:02:17-INFO--------------------	Starting simulation	-------------------
# 17-07-24 16:02:17-INFO-pax    0  got to dest at                           2024-07-17 14:19:08
# 17-07-24 16:02:18-INFO-pax    1  got to dest at                           2024-07-17 15:45:37
# 17-07-24 16:02:18-INFO-pax    2  got to dest at                           2024-07-17 16:15:22
# 17-07-24 16:02:18-INFO-pax    3  got to dest at                           2024-07-17 16:28:10
# 17-07-24 16:02:18-INFO-pax    4  got to dest at                           2024-07-17 16:36:49
# 17-07-24 16:02:18-INFO-veh    1  quitted shift                            2024-07-17 20:07:31
# 17-07-24 16:02:18-INFO-veh    2  quitted shift                            2024-07-17 20:07:31
# 17-07-24 16:02:18-INFO--------------------	Simulation over		-------------------
# 17-07-24 16:02:18-INFO-queue of requests 0
# 17-07-24 16:02:18-WARNING-simulation time 0.1 s
# 17-07-24 16:02:18-WARNING-assertion tests for simulation results - passed
# 17-07-24 16:02:18-WARNING-Setting up 4h simulation at 2024-07-17 15:03:18 for 2 vehicles and 5 passengers in Nootdorp, Netherlands
# 17-07-24 16:02:18-INFO--------------------	Starting simulation	-------------------
# 17-07-24 16:02:18-INFO-pax    0  got to dest at                           2024-07-17 15:07:21
# 17-07-24 16:02:18-INFO-pax    1  got to dest at                           2024-07-17 16:16:24
# 17-07-24 16:02:18-INFO-pax    2  got to dest at                           2024-07-17 16:59:10
# 17-07-24 16:02:18-INFO-pax    3  got to dest at                           2024-07-17 17:52:17
# 17-07-24 16:02:18-INFO-pax    4  got to dest at                           2024-07-17 18:00:38
# 17-07-24 16:02:18-INFO-veh    2  quitted shift                            2024-07-17 21:03:17
# 17-07-24 16:02:18-INFO-veh    1  quitted shift                            2024-07-17 21:03:17
# 17-07-24 16:02:18-INFO--------------------	Simulation over		-------------------
# 17-07-24 16:02:18-INFO-queue of requests 0
# 17-07-24 16:02:18-WARNING-simulation time 0.1 s
# 17-07-24 16:02:18-WARNING-assertion tests for simulation results - passed
# Total waiting time: 631.0s in first simulation and 455.0s in the second.
# 17-07-24 16:02:18-WARNING-Setting up 4h simulation at 2024-07-17 15:12:51 for 5 vehicles and 5 passengers in Nootdorp, Netherlands
# 17-07-24 16:02:18-WARNING-simulation time 0.1 s
# 17-07-24 16:02:18-WARNING-assertion tests for simulation results - passed
# -nP_5-nV_5-dt_20240717160218435598 2024-07-17 16:02:18.709927 end
# 17-07-24 16:02:18-WARNING-Setting up 4h simulation at 2024-07-17 14:10:37 for 5 vehicles and 5 passengers in Nootdorp, Netherlands
# 17-07-24 16:02:18-WARNING-simulation time 0.1 s
# 17-07-24 16:02:18-WARNING-assertion tests for simulation results - passed
# -nP_5-nV_5-dt_20240717160218709927 2024-07-17 16:02:19.010077 end
# 17-07-24 16:02:19-WARNING-Setting up 4h simulation at 2024-07-17 14:59:07 for 10 vehicles and 5 passengers in Nootdorp, Netherlands
# 17-07-24 16:02:19-WARNING-simulation time 0.1 s
# 17-07-24 16:02:19-WARNING-assertion tests for simulation results - passed
# -nP_5-nV_10-dt_20240717160219010077 2024-07-17 16:02:19.310526 end
# 17-07-24 16:02:19-WARNING-Setting up 4h simulation at 2024-07-17 14:02:54 for 10 vehicles and 5 passengers in Nootdorp, Netherlands
# 17-07-24 16:02:19-WARNING-simulation time 0.1 s
# 17-07-24 16:02:19-WARNING-assertion tests for simulation results - passed
# -nP_5-nV_10-dt_20240717160219310526 2024-07-17 16:02:19.621732 end
# 17-07-24 16:02:19-WARNING-Setting up 4h simulation at 2024-07-17 14:26:52 for 5 vehicles and 10 passengers in Nootdorp, Netherlands
# 17-07-24 16:02:19-WARNING-simulation time 0.2 s
# 17-07-24 16:02:19-WARNING-assertion tests for simulation results - passed
# -nP_10-nV_5-dt_20240717160219621988 2024-07-17 16:02:20.035555 end
# 17-07-24 16:02:20-WARNING-Setting up 4h simulation at 2024-07-17 14:19:20 for 5 vehicles and 10 passengers in Nootdorp, Netherlands
# 17-07-24 16:02:20-WARNING-simulation time 0.2 s
# 17-07-24 16:02:20-WARNING-assertion tests for simulation results - passed
# -nP_10-nV_5-dt_20240717160220035555 2024-07-17 16:02:20.472251 end
# 17-07-24 16:02:20-WARNING-Setting up 4h simulation at 2024-07-17 15:16:50 for 10 vehicles and 10 passengers in Nootdorp, Netherlands
# 17-07-24 16:02:20-WARNING-simulation time 0.2 s
# 17-07-24 16:02:20-WARNING-assertion tests for simulation results - passed
# -nP_10-nV_10-dt_20240717160220473243 2024-07-17 16:02:20.880804 end
# 17-07-24 16:02:20-WARNING-Setting up 4h simulation at 2024-07-17 14:14:32 for 10 vehicles and 10 passengers in Nootdorp, Netherlands
# 17-07-24 16:02:21-WARNING-simulation time 0.2 s
# 17-07-24 16:02:21-WARNING-assertion tests for simulation results - passed
# -nP_10-nV_10-dt_20240717160220881807 2024-07-17 16:02:21.348251 end
# 17-07-24 16:02:21-WARNING-Setting up 4h simulation at 2024-07-17 14:07:21 for 5 vehicles and 20 passengers in Nootdorp, Netherlands
# 17-07-24 16:02:21-WARNING-simulation time 0.4 s
# 17-07-24 16:02:21-WARNING-assertion tests for simulation results - passed
# -nP_20-nV_5-dt_20240717160221348251 2024-07-17 16:02:21.971316 end
# 17-07-24 16:02:22-WARNING-Setting up 4h simulation at 2024-07-17 14:06:51 for 5 vehicles and 20 passengers in Nootdorp, Netherlands
# 17-07-24 16:02:22-WARNING-simulation time 0.4 s
# 17-07-24 16:02:22-WARNING-assertion tests for simulation results - passed
# -nP_20-nV_5-dt_20240717160221971316 2024-07-17 16:02:22.582419 end
# 17-07-24 16:02:22-WARNING-Setting up 4h simulation at 2024-07-17 14:05:30 for 10 vehicles and 20 passengers in Nootdorp, Netherlands
# 17-07-24 16:02:23-WARNING-simulation time 0.4 s
# 17-07-24 16:02:23-WARNING-assertion tests for simulation results - passed
# -nP_20-nV_10-dt_20240717160222582419 2024-07-17 16:02:23.177650 end
# 17-07-24 16:02:23-WARNING-Setting up 4h simulation at 2024-07-17 14:14:23 for 10 vehicles and 20 passengers in Nootdorp, Netherlands
# 17-07-24 16:02:23-WARNING-simulation time 0.4 s
# 17-07-24 16:02:23-WARNING-assertion tests for simulation results - passed
# -nP_20-nV_10-dt_20240717160223178714 2024-07-17 16:02:23.811297 end
# 17-07-24 16:02:24-WARNING-Setting up 4h simulation at 2024-07-17 15:03:18 for 2 vehicles and 5 passengers in Nootdorp, Netherlands
# 17-07-24 16:02:24-INFO--------------------	Starting simulation	-------------------
# 17-07-24 16:02:24-INFO-veh    1  opted-out from the system                2024-07-17 15:03:18
# 17-07-24 16:02:24-INFO-veh    2  opted-out from the system                2024-07-17 15:03:18
# 17-07-24 16:02:24-INFO-pax    0  has no offers                            2024-07-17 15:13:33
# 17-07-24 16:02:24-INFO-pax    0  lost his patience and left the system    2024-07-17 15:13:33
# 17-07-24 16:02:24-INFO-pax    1  has no offers                            2024-07-17 16:20:20
# 17-07-24 16:02:24-INFO-pax    1  lost his patience and left the system    2024-07-17 16:20:20
# 17-07-24 16:02:24-INFO-pax    2  has no offers                            2024-07-17 17:04:55
# 17-07-24 16:02:24-INFO-pax    2  lost his patience and left the system    2024-07-17 17:04:55
# 17-07-24 16:02:24-INFO-pax    3  has no offers                            2024-07-17 17:56:34
# 17-07-24 16:02:24-INFO-pax    3  lost his patience and left the system    2024-07-17 17:56:34
# 17-07-24 16:02:24-INFO-pax    4  has no offers                            2024-07-17 18:04:33
# 17-07-24 16:02:24-INFO-pax    4  lost his patience and left the system    2024-07-17 18:04:33
# 17-07-24 16:02:24-INFO--------------------	Simulation over		-------------------
# 17-07-24 16:02:24-INFO-queue of requests 0
# 17-07-24 16:02:24-WARNING-simulation time 0.1 s
# 17-07-24 16:02:24-WARNING-assertion tests for simulation results - passed
