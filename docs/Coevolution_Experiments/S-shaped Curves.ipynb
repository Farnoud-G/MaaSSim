# %%
import math
from numpy import log as ln
import matplotlib.pyplot as plt          
import numpy as np
import seaborn as sns
import random

# %%
1-1e-10
# Out:
# 0.9999999999

# %%
9e-10

# %%
pre_cu_i = 1-1e-2 # cumulative utility 
pre_cu_j = 0.5
B_learning = 1

pre_u_i = ln((1/pre_cu_i)-1)  # first we calculate the previous utility for the previous cumulative utility
u_i = pre_u_i + 1 # 
cu = 1/(1+math.exp(B_learning*u_i))

cu
# Out:
# 0.9481793414012446

# %%
x = []
y = []
B_learning = 0.75

for i in range(-10,10):
sns.lineplot(x=x, y=y)
ax.set_title('WOM & Marketing')
# Out:
# Text(0.5, 1.0, 'WOM & Marketing')

# %%
# A logistic function or logistic curve is a common S-shaped curve (sigmoid curve) with equation

x = []
y = []
k = 1
L = 2
i_0 = 0

for i in range(-10,10):
    
    f = L/(1+math.exp(-k*(i-i_0)))
    x.append(i)
    y.append(f)
    
fig, ax = plt.subplots(figsize=(8,8))
sns.lineplot(x=x, y=y)
# Out:
# <AxesSubplot:>

# %%
pre_att_j = 1
pre_att_i = 0.01
B_learning = 1
x = []
y = []

for t in range(0,20):
    
    pre_cu_i = ln((1/pre_att_i)-1)
    x.append(t)
    y.append(pre_att_i)
    cu_i = pre_cu_i + pre_att_i - pre_att_j
    att_i = 1/(1+math.exp(B_learning*(cu_i)))
    pre_att_i = att_i

fig, ax = plt.subplots(figsize=(8,8))
sns.lineplot(x=x, y=y)
# Out:
# <AxesSubplot:>

# %%
pre_att_j = 1
yt = 0.01
B_learning = 1
x = []
y = []
g = 0.5

for t in range(0,20):
    pre_att_j = np.random.normal(-0.5,0.2)
    x.append(t)
    y.append(pre_att_i)
    yt = 1/(1+math.exp(B_learning*((1-g)*ln((1/pre_att_i)-1) + g*(yt - pre_att_j))))
    pre_att_i = att_i

fig, ax = plt.subplots(figsize=(8,8))
sns.lineplot(x=x, y=y)
# Out:
# <AxesSubplot:>

# %%
pre_att_j = 1
pre_att_i = 0.001
B_learning = 1
x = []
y = []
g = 0.1

for t in range(0,40):
    
    # pre_att_j = np.random.normal(1,0.2)
    pre_cu_i = ln((1/pre_att_i)-1)
    x.append(t)
    y.append(pre_att_i)
    cu_i = pre_cu_i + (pre_att_i - pre_att_j)
    att_i = 1/(1+math.exp(B_learning*(cu_i)))
    pre_att_i = att_i

fig, ax = plt.subplots(figsize=(8,8))
sns.lineplot(x=x, y=y)
# Out:
# <AxesSubplot:>

# %%
pre_att_j = 1
pre_att_i = 0.1
B_learning = 1
fig, ax = plt.subplots(figsize=(8,8))

for i in range(1,10):
    pre_att_i = 10**(-i)
    x = []
    y = []
    for t in range(0,30):
        pre_cu_i = ln((1/pre_att_i)-1)
        x.append(t)
        y.append(pre_att_i)
        cu_i = pre_cu_i + pre_att_i - pre_att_j
        att_i = 1/(1+math.exp(B_learning*(cu_i)))
        pre_att_i = att_i
    
    sns.lineplot(x=x, y=y)

# %%
RW = -0.4
actual_inc = -0.3
*(RW - actual_inc)/abs(RW)
# Out:
# -0.25000000000000006

# %%
cu_i = (6.388668e-07) - (0.559307)
att_i = 1/(1+math.exp(B_learning*(cu_i)))


learning_d = 1
pre_EXPERIENCE_U = 0.001#2.8300424373561125e-303
U_dif =40.57271980538072
x=ln((1/pre_EXPERIENCE_U)-1)
print(x)
u = 1/(1+math.exp(learning_d*(x+U_dif)))
print(u)
# Out:
# 6.906754778648554
# 2.3984252324507298e-21

# %%
ln(1/0.001)
# Out:
# 6.907755278982137

# %%
1/(1+math.exp(params.d2d.learning_d*(ln((1/row.pre_EXPERIENCE_U)-1)+row.U_dif)))

# %%
# Learning from experiences

RW = 40
actual_inc = 60
pre_att_i = 0.001
B_learning = 1
a = 1
x = []
y = []

for t in range(0,30):
    
    pre_cu_i = ln((1/pre_att_i)-1)
    x.append(t)
    y.append(pre_att_i)
    cu_i = pre_cu_i + a*(RW - actual_inc)/abs(RW)
    att_i = 1/(1+math.exp(B_learning*(cu_i)))
    pre_att_i = att_i

fig, ax = plt.subplots(figsize=(8,8))
sns.lineplot(x=x, y=y)
ax.set_title('Experience')
# Out:
# Text(0.5, 1.0, 'Experience')

# %%
# remember that the attitude is always in 0<attitude<1 range

pre_att_i = 0.5 # attitude toward alternative i
pre_att_j = 1  # attitude toward alternative j
B_learning = 1  #learning speed in range 0<B_learning<1
mu = 10
att_alt_choice = 0.5

x = []
y = []
p = []

for t in range(1,12):
    
    y.append(pre_att_i)
        
    pre_cu_i = ln((1/pre_att_i)-1)  # first we calculate the previous cumulative utility from previous attitude
    cu_i = pre_cu_i + pre_att_i - pre_att_j # we update the cumulative utility
    att_i = 1/(1+math.exp(B_learning*cu_i))  # we calculate the new attitude wrt updated cumulative utility
    prob = (math.exp(mu*att_i))/(math.exp(mu*att_i) + math.exp(mu*att_alt_choice))
    
    x.append(t)
    p.append(prob)
    
    pre_att_i = att_i

fig, ax = plt.subplots(figsize=(8,8))
sns.lineplot(x=x, y=y)
# Out:
# <AxesSubplot:>

# %%
# remember that the attitude is always in 0<attitude<1 range

pre_att_i = 0.9 # attitude toward alternative i
pre_att_j = 1  # attitude toward alternative j
B_learning = 0.3  #learning speed in range 0<B_learning<1
mu = 5
att_alt_choice = 0.2

x = []
y = []
p = []
pre = []

for t in range(1,200):
    if t>45:
        pre_att_j=0
    if t>50:
        pre_att_j=1
    if t>80:
        pre_att_j=0.5
    if t>80:
        pre_att_j = 0.25+random.random()/10
    
    y.append(pre_att_i)
    pre.append(pre_att_j)
        
    pre_cu_i = ln((1/pre_att_i)-1)  # first we calculate the previous cumulative utility from previous attitude
    cu_i = pre_cu_i + pre_att_i - pre_att_j # we update the cumulative utility
    att_i = 1/(1+math.exp(B_learning*cu_i))  # we calculate the new attitude wrt updated cumulative utility
    prob = (math.exp(mu*att_i))/(math.exp(mu*att_i) + math.exp(mu*att_alt_choice))
    
    x.append(t)
    p.append(prob)
    
    pre_att_i = att_i

fig, ax = plt.subplots(figsize=(8,8))
sns.lineplot(x=x, y=y)
sns.lineplot(x=x, y=pre, color = 'red')
# Out:
# <AxesSubplot:>

# %%
pre_att_j = 1
pre_att_i = 0.0001
B_learning = 1
fig, ax = plt.subplots(figsize=(8,8))

x = []
y = []
for t in range(0,100):
    
    if t>10:
        pre_att_j = 0
    if t>20:
        pre_att_j = 0.5
    if t>30:
        pre_att_j = 1
    
    pre_cu_i = ln((1/pre_att_i)-1)
    x.append(t)
    y.append(pre_att_i)
    cu_i = pre_cu_i + pre_att_i - pre_att_j
    att_i = 1/(1+math.exp(B_learning*(cu_i)))
    pre_att_i = att_i

sns.lineplot(x=x, y=y)
# Out:
# <AxesSubplot:>

# %%
pre_att_j = 1
pre_att_i = 0.0001
B_learning = 1
fig, ax = plt.subplots(figsize=(8,8))

x = []
y = []
for t in range(0,500):
    
    pre_att_j = random.random()
    pre_cu_i = ln((1/pre_att_i)-1)
    x.append(t)
    y.append(pre_att_i)
    cu_i = pre_cu_i + pre_att_i - pre_att_j
    att_i = 1/(1+math.exp(B_learning*(cu_i)))
    pre_att_i = att_i

sns.lineplot(x=x, y=y)
# Out:
# <AxesSubplot:>

# %%
# remember that the attitude is always in 0<attitude<1 range

pre_att_i = 0.5 # attitude toward alternative i
B_learning = 1  #learning speed in range 0<B_learning<1
mu = 10
att_alt_choice = 0.5

x = []
y = []
p = []

for t in range(1,100):
    
    y.append(pre_att_i)
    pre_att_j = random.random()  # attitude toward alternative j
    
    pre_cu_i = ln((1/pre_att_i)-1)  # first we calculate the previous cumulative utility from previous attitude
    cu_i = pre_cu_i + pre_att_i - pre_att_j # we update the cumulative utility
    att_i = 1/(1+math.exp(B_learning*cu_i))  # we calculate the new attitude wrt updated cumulative utility
    prob = (math.exp(mu*att_i))/(math.exp(mu*att_i) + math.exp(mu*att_alt_choice))
    
    x.append(t)
    p.append(prob)
    
    pre_att_i = att_i

fig, ax = plt.subplots(figsize=(8,8))
sns.lineplot(x=x, y=y)
# Out:
# <AxesSubplot:>

# %%
# remember that the attitude is always in 0<attitude<1 range

pre_att_i = 0.5 # attitude toward alternative i
B_learning = 1  #learning speed in range 0<B_learning<1
mu = 10
att_alt_choice = 0.5
RW = 40

x = []
y = []
p = []

for t in range(1,100):
    
    y.append(pre_att_i)
    last_experienced_income = random.randint(0,80)  # attitude toward alternative j
    
    pre_cu_i = ln((1/pre_att_i)-1)  # first we calculate the previous cumulative utility from previous attitude
    cu_i = pre_cu_i + (RW - last_experienced_income)/RW # we update the cumulative utility
    att_i = 1/(1+math.exp(B_learning*cu_i))  # we calculate the new attitude wrt updated cumulative utility
    prob = (math.exp(mu*att_i))/(math.exp(mu*att_i) + math.exp(mu*att_alt_choice))
    
    x.append(t)
    p.append(prob)
    
    pre_att_i = att_i

fig, ax = plt.subplots(figsize=(8,8))
sns.lineplot(x=x, y=y)
# Out:
# <AxesSubplot:>

# %%
# remember that the attitude is always in 0<attitude<1 range

pre_att_i = 0.5 # attitude toward alternative i
B_learning = 1  #learning speed in range 0<B_learning<1
mu = 10
att_alt_choice = 0.5
RW = 40

last_experienced_income = 40  # attitude toward alternative j

pre_cu_i = ln((1/pre_att_i)-1)  # first we calculate the previous cumulative utility from previous attitude
cu_i = pre_cu_i + (RW - last_experienced_income)/RW # we update the cumulative utility
att_i = 1/(1+math.exp(B_learning*cu_i))  # we calculate the new attitude wrt updated cumulative utility
prob = (math.exp(mu*att_i))/(math.exp(mu*att_i) + math.exp(mu*att_alt_choice))

print('att_i= ',att_i)
print('prob= ',prob)
# Out:
# att_i=  0.658417500561683
# prob=  0.8297949881638641

# %%
================================================================

# %%
# Learning from experiences
fig, ax = plt.subplots(figsize=(16,5))

RW = 40
E_u = 0.01
M_u = 0.5
W_u = 0.5
# U = 0
B_learning = 1
a = 1
x = []
ye = []; ym = []; yw = []; yu = []

for t in range(0,50):
    
    x.append(t)
    ye.append(E_u)
    ym.append(M_u)
    yw.append(W_u)
    
    if t<20:
        M_u = 1/(1+math.exp(B_learning*(ln((1/M_u)-1) + 1.5*(M_u - 1))))
    if 9<t<30:
        W_u = 1/(1+math.exp(B_learning*(ln((1/W_u)-1) + a*(W_u - 1))))
    if 29<t<50:
        W_u = 1/(1+math.exp(B_learning*(ln((1/W_u)-1) + a*(W_u - 0))))
    if 19<t<40:
        E_u = 1/(1+math.exp(B_learning*(ln((1/E_u)-1) + 1*(RW - 60)/abs(RW))))
    if 39<t<50:
        E_u = 1/(1+math.exp(B_learning*(ln((1/E_u)-1) + 1*(RW - 20)/abs(RW))))
    
    U = (1/3)*E_u + (1/3)*M_u + (1/3)*W_u
    yu.append(U)
    

sns.lineplot(x=x, y=ye, label='Experience')
sns.lineplot(x=x, y=ym, label='Marketing')
sns.lineplot(x=x, y=yw, label='WOM')
sns.lineplot(x=x, y=yu, label='Perceived utility')
# Out:
# <AxesSubplot:>

# %%
random.random()
# Out:
# 0.1615552192037134

# %%
fig, ax = plt.subplots(figsize=(16,4))

RW = 40
actual_inc = 60
pre_att_i = 0.001
B_learning = 1
a = 1
x = []
y = []

for t in range(0,30):
    
    pre_cu_i = ln((1/pre_att_i)-1)
    x.append(t)
    y.append(pre_att_i)
    cu_i = pre_cu_i + a*(RW - actual_inc)/abs(RW)
    att_i = 1/(1+math.exp(B_learning*(cu_i)))
    pre_att_i = att_i

sns.lineplot(x=x, y=y)

RW = 40
actual_inc = 60
pre_att_i = 0.001
B_learning = 1
a = 1
x = []
y = []

for t in range(0,30):
    
    pre_cu_i = ln((1/pre_att_i)-1)
    x.append(t)
    y.append(pre_att_i)
    cu_i = pre_cu_i - 0.5
    att_i = 1/(1+math.exp(B_learning*(cu_i)))
    pre_att_i = att_i

sns.lineplot(x=x, y=y)
# Out:
# <AxesSubplot:>

# %%
sns.set(rc={"figure.dpi":500, 'savefig.dpi':500})
sns.set(palette='tab10',font_scale=1.5)#, rc={'axes.facecolor':'lightblue', 'figure.facecolor':'lightgreen'},)
sns.set_style('whitegrid')
fig, ax = plt.subplots(figsize=(12,8))
# plt.subplots_adjust(wspace=0.3, hspace=0.4)
sns.despine(left=True)
RW = 40
actual_inc = 60
pre_att_i = 0.001
B_learning = 1
a = 1
x = []
y = []

for t in range(0,29):
    
    pre_cu_i = ln((1/pre_att_i)-1)
    x.append(t)
    y.append(pre_att_i)
    cu_i = pre_cu_i + a*(RW - actual_inc)/abs(RW)
    att_i = 1/(1+math.exp(B_learning*(cu_i)))
    pre_att_i = att_i

    
# ax.hlines([0], 0, 48, lw=3, linestyles='dashed', colors='C3')
# ax.hlines([0.5], 0, 48, lw=3, linestyles='dashed', colors='C7')
# ax.hlines([1], 0, 48, lw=3, linestyles='dashed', colors='C2')
# ax.vlines([40], 0, 1.2, lw=3, linestyles='dashed', colors='C7')


# ax.annotate('Learning', xy =(-5.5,1.2), fontweight='bold')
# ax.annotate('Negative', xy =(30.5,0), fontweight='bold')
# ax.annotate('Unpractised', xy =(-5.5,0), fontweight='bold')
# ax.annotate('Neutral', xy =(30.5,0.5), fontweight='bold')
# ax.annotate('Semi-practised', xy =(-5.5,0.5), fontweight='bold')
# ax.annotate('Positive', xy =(30.5,1), fontweight='bold')
# ax.annotate('Practised', xy =(-5.5,1), fontweight='bold')


sns.lineplot(x=x, y=y, lw=4, marker='o', markersize=7, color='black')


ax.grid(axis='x')
ax.set(xlim=(-1,35), ylim=(-0.05,1.2), xlabel='Cumulative utility', ylabel='Utility', yticks=[0,0.5,1],
      xticks=[])
plt.tight_layout()
plt.savefig('Fig_methodsn.png')

# %%
# FOR DIAGRAM
sns.set(rc={"figure.dpi":200, 'savefig.dpi':200})
sns.set(palette='tab10',font_scale=3)#, rc={'axes.facecolor':'lightblue', 'figure.facecolor':'lightgreen'},)
sns.set_style('dark')
fig, ax = plt.subplots(figsize=(12,8))
# plt.subplots_adjust(wspace=0.3, hspace=0.4)
# sns.despine(left=True)
RW = 40
actual_inc = 60
pre_att_i = 0.001
B_learning = 1
a = 1
x = []
y = []

for t in range(0,29):
    
    pre_cu_i = ln((1/pre_att_i)-1)
    x.append(t)
    y.append(pre_att_i)
    cu_i = pre_cu_i + a*(RW - actual_inc)/abs(RW)
    att_i = 1/(1+math.exp(B_learning*(cu_i)))
    pre_att_i = att_i

    
# ax.hlines([0], 0, 48, lw=3, linestyles='dashed', colors='C3')
# ax.hlines([0.5], 0, 48, lw=3, linestyles='dashed', colors='C7')
# ax.hlines([1], 0, 48, lw=3, linestyles='dashed', colors='C2')
# ax.vlines([40], 0, 1.2, lw=3, linestyles='dashed', colors='C7')


# ax.annotate('Learning', xy =(-5.5,1.2), fontweight='bold')
# ax.annotate('Negative', xy =(30.5,0), fontweight='bold')
# ax.annotate('Unpractised', xy =(-5.5,0), fontweight='bold')
# ax.annotate('Neutral', xy =(30.5,0.5), fontweight='bold')
# ax.annotate('Semi-practised', xy =(-5.5,0.5), fontweight='bold')
# ax.annotate('Positive', xy =(30.5,1), fontweight='bold')
# ax.annotate('Practised', xy =(-5.5,1), fontweight='bold')


sns.lineplot(x=x, y=y, lw=4, markersize=7, color='red')


ax.grid(axis='x')
ax.set(xlim=(-1,29), ylim=(-0.05,1.05), xlabel='Cumulative utility', ylabel='Perceived Utility Component', yticks=[0,0.5,1],
      xticks=[])
plt.tight_layout()
plt.savefig('Fig_forDiagram.png')

# %%
# FOR DIAGRAM
sns.set(rc={"figure.dpi":500, 'savefig.dpi':500})
sns.set(palette='tab10',font_scale=3)#, rc={'axes.facecolor':'lightblue', 'figure.facecolor':'lightgreen'},)
sns.set_style('white')
fig, ax = plt.subplots(figsize=(12,8))
# plt.subplots_adjust(wspace=0.3, hspace=0.4)
sns.despine(left=True)
RW = 40
actual_inc = 60
pre_att_i = 0.001
B_learning = 1
a = 1
x = []
y = []

for t in range(0,29):
    
    pre_cu_i = ln((1/pre_att_i)-1)
    x.append(t)
    y.append(pre_att_i)
    cu_i = pre_cu_i + a*(RW - actual_inc)/abs(RW)
    att_i = 1/(1+math.exp(B_learning*(cu_i)))
    pre_att_i = att_i

    
# ax.hlines([0], 0, 48, lw=3, linestyles='dashed', colors='C3')
# ax.hlines([0.5], 0, 48, lw=3, linestyles='dashed', colors='C7')
# ax.hlines([1], 0, 48, lw=3, linestyles='dashed', colors='C2')
# ax.vlines([40], 0, 1.2, lw=3, linestyles='dashed', colors='C7')


# ax.annotate('Learning', xy =(-5.5,1.2), fontweight='bold')
# ax.annotate('Negative', xy =(30.5,0), fontweight='bold')
# ax.annotate('Unpractised', xy =(-5.5,0), fontweight='bold')
# ax.annotate('Neutral', xy =(30.5,0.5), fontweight='bold')
# ax.annotate('Semi-practised', xy =(-5.5,0.5), fontweight='bold')
# ax.annotate('Positive', xy =(30.5,1), fontweight='bold')
# ax.annotate('Practised', xy =(-5.5,1), fontweight='bold')


sns.lineplot(x=x, y=y, lw=4, markersize=7, color='dodgerblue')


ax.grid(axis='x')
ax.set(xlim=(-1,29), ylim=(-0.05,1.05), yticks=[0,0.5,1],
      xticks=[])
plt.tight_layout()
plt.savefig('Fig_forDiagram2.png')

# %%
a = [11,2,3,4,5]
a[3]
# Out:
# 4

# %%
sns.set(rc={"figure.dpi":200, 'savefig.dpi':200})
sns.set(palette='tab10',font_scale=1)#, rc={'axes.facecolor':'lightblue', 'figure.facecolor':'lightgreen'},)
sns.set_style('white')
fig, ax = plt.subplots(figsize=(5,3))
# plt.subplots_adjust(wspace=0.3, hspace=0.4)
sns.despine(left=True)

#---------------------------------------------------------------------
RW = 40
actual_inc = 60
pre_att_i = 0.001
B_learning = 1
a = 1

incs = [50, 60, 80, 0, 20, 30]
actual_inc = [i for i in incs for f in range(0,10)]
x = []
y = []
r = 60

for t in range(0,r):
    
    pre_cu_i = ln((1/pre_att_i)-1)
    x.append(t)
    y.append(pre_att_i)
    cu_i = pre_cu_i + a*(RW - actual_inc[t])/abs(RW)
    att_i = 1/(1+math.exp(B_learning*(cu_i)))
    pre_att_i = att_i

sns.lineplot(x=x, y=y, lw=2, markersize=5, color='blue', ax=ax)
#------------------------------------------------------------------------
ax2 = ax.twinx()

x = []
y = []
ue = 0.001
alfa = 0.2
uact = actual_inc

for t in range(0,r):
    x.append(t)
    y.append(ue)
    ue = (1-alfa)*ue + alfa*uact[t]


sns.lineplot(x=x, y=y, lw=2, markersize=5, color='red', ax=ax2)
#------------------------------------------------------------------------

ax.grid(axis='x')
sns.despine(left=True)
# ax.set(xlim=(-1,35), ylim=(-0.05,1.2), xlabel='Cumulative utility', ylabel='Utility', yticks=[0,0.5,1],
#       xticks=[])
plt.tight_layout()
# plt.savefig('Fig_methodsn.png')

# %%
platform control levers:
    1. trip fare
    2. commission rate
    3. discount
    4. self-supply

# %%
Base scenario: trip fare = 1.21, commission rate = 0%

Results:
    1- trip fare+  
    2- trip fare+  commission rate+
    3- trip fare-  
    4- trip fare-  commission rate+
    5- selfsupply
    6- asset-heavy, autonomous and electric fleets 
    
    7- best way to enlarge the scale (with out wasting money) would be to apply discounts for travellers who assign less utility to rs than pt.

# %%
tragedy of commons
early adopters and late adopters

# %%
Important remarks:
    
1- Since the utilities are changing in (0,1), each driver should converge to a specific attitude 0 or 1.
After a while. This does not happen in Arjan's or Djavadians model.

2- The stability of on driver depends on endogenous factor of EXPERIENCE_U and WOM and Marketing. So we
will see the complete convergance will happen when the marketing reaches to max effect 1. and other drivers
converge (wom).

3- large scales on both demand and supply sides brings an extra utility in terms of lower pick up times.

4- increasing we increase the coefficient of the diff in experience, agents are learning faster.

5- in the basic model drivers are more sensitive than passengers to the changes in system. Because 
passengers are considering other factors like trip fare beside waiting time. That is why driver scale obeys
passenger scale. This prevents the network effect to happen. however, to increase passenger sensitivity we
increase the wait time coefficient in the utility formula.

6- in some scenarios with high trip fare we can observe that the coevolution does not experience the network
effect ant after a small growth in the initial phase it remains same. This is because of zero experience
utility on demand side. so passenger always asign lower utility to the rs but they use it occasionally, 
since the model is probabilistic. On driver side we will have the same drivers but what about demand?!

7- According to literature wom has twice greater effect than traditional marketing but whith slower diffusion
this can be reflected to diffusion speed and betas.

8- not now but in future it would be interesting to add memory decay in the learning formula.

9- it seems the platform scale highly depends on the travllers. waiting time has limmited effect on 
travellers number. therefor, the only way to enlarge the scale a little more is to play with trip fare 
but through applying discounts for the traveller choosing pt. 

10- dont forget to fix the positions for drivers.

11- dont forget to calculate the platform profit from the trip fares assigned to passengers. otherwise, 
in case of discount you will get a wrong profit value.
