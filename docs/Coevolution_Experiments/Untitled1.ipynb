# %%
import pandas as pd
import seaborn as sns
import numpy as np
from scipy import stats

# %%
df = pd.read_csv('BostonHousing.csv')
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df = pd.read_csv('BostonHousing.csv')
df = df.loc[df.crim<3.613524+(3*)]
df = df.loc[df.zn<80.00]
df = df.loc[df.indus<21.89000]
df = df.loc[df.nox<0.74000]
df = df.loc[df.rm<7.46040]

# %%
df[(np.abs(stats.zscore(df)) < 3).all(axis=1)]
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
stats.zscore(df)
# Out:
#          crim        zn     indus      chas       nox        rm       age  \
# 0   -0.419782  0.284830 -1.287909 -0.272599 -0.144217  0.413672 -0.120013
# 1   -0.417339 -0.487722 -0.593381 -0.272599 -0.740262  0.194274  0.367166
# 2   -0.417342 -0.487722 -0.593381 -0.272599 -0.740262  1.282714 -0.265812
# 3   -0.416750 -0.487722 -1.306878 -0.272599 -0.835284  1.016303 -0.809889
# 4   -0.412482 -0.487722 -1.306878 -0.272599 -0.835284  1.228577 -0.511180
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.413229 -0.487722  0.115738 -0.272599  0.158124  0.439316  0.018673
# 502 -0.415249 -0.487722  0.115738 -0.272599  0.158124 -0.234548  0.288933
# 503 -0.413447 -0.487722  0.115738 -0.272599  0.158124  0.984960  0.797449
# 504 -0.407764 -0.487722  0.115738 -0.272599  0.158124  0.725672  0.736996
# 505 -0.415000 -0.487722  0.115738 -0.272599  0.158124 -0.362767  0.434732
#
#           dis       rad       tax   ptratio         b     lstat      medv
# ...

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df = pd.read_csv('BostonHousing.csv')
df = df.loc[df.crim<12.91142]
df = df.loc[df.zn<80.00]
df = df.loc[df.indus<21.89000]
df = df.loc[df.nox<0.74000]
df = df.loc[df.rm<7.46040]
df = df.loc[df.age<100.00]
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df.quantile(0.95)
# Out:
# crim        12.91142
# zn          80.00000
# indus       21.89000
# chas         0.00000
# nox          0.74000
# rm           7.46040
# age        100.00000
# dis          7.96530
# rad         24.00000
# tax        666.00000
# ptratio     21.00000
# b          396.90000
# lstat       25.72400
# medv        41.46000
# Name: 0.95, dtype: float64

# %%
plt.hist(df.ptratio, bins=20)
# Out:
# (array([ 15.,   0.,   1.,   1.,  41.,  17.,   3.,  12.,  26.,   9.,  26.,
#          43.,  50.,  26.,  27.,  13., 140.,  38.,  16.,   2.]),
#  array([12.6 , 13.07, 13.54, 14.01, 14.48, 14.95, 15.42, 15.89, 16.36,
#         16.83, 17.3 , 17.77, 18.24, 18.71, 19.18, 19.65, 20.12, 20.59,
#         21.06, 21.53, 22.  ]),
#  <BarContainer object of 20 artists>)

# %%
df.corr()
# Out:
#              crim        zn     indus  chas       nox        rm       age  \
# crim     1.000000 -0.275605  0.558568   NaN  0.593061 -0.211972  0.464684
# zn      -0.275605  1.000000 -0.523832   NaN -0.517521  0.309219 -0.553381
# indus    0.558568 -0.523832  1.000000   NaN  0.750353 -0.397729  0.626551
# chas          NaN       NaN       NaN   NaN       NaN       NaN       NaN
# nox      0.593061 -0.517521  0.750353   NaN  1.000000 -0.284938  0.737426
# rm      -0.211972  0.309219 -0.397729   NaN -0.284938  1.000000 -0.217038
# age      0.464684 -0.553381  0.626551   NaN  0.737426 -0.217038  1.000000
# dis     -0.485754  0.662670 -0.688332   NaN -0.768210  0.181931 -0.735640
# rad      0.857467 -0.297583  0.579798   NaN  0.603695 -0.173736  0.430951
# tax      0.792614 -0.297509  0.710779   NaN  0.654684 -0.271697  0.484942
# ptratio  0.362638 -0.399954  0.396446   NaN  0.195031 -0.355621  0.262046
# b       -0.511257  0.175121 -0.359677   NaN -0.394418  0.102258 -0.278129
# ...

# %%
df = df.dropna()
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
# Out:
# RangeIndex(start=0, stop=506, step=1)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df.crim)

# %%
df.quantile(0.5)
# Out:
# crim         0.25651
# zn           0.00000
# indus        9.69000
# chas         0.00000
# nox          0.53800
# rm           6.20850
# age         77.50000
# dis          3.20745
# rad          5.00000
# tax        330.00000
# ptratio     19.05000
# b          391.44000
# lstat       11.36000
# medv        21.20000
# Name: 0.5, dtype: float64

# %%
df.drop(index=1, inplace=True)
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 5    0.02985   0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 2       17.8  392.83   4.03  34.7
# ...

# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22736/1316919942.py in <module>
#       1 import pandas as pd
# ----> 2 import torch
#
# ModuleNotFoundError: No module named 'torch'

# %%
filename = 'trips.txt'

with open('trips.txt', "r") as f:
    # for line in f:
    # look at line in loop
        # print(line, end='')
# Out:
#   File "C:\Users\farno\AppData\Local\Temp/ipykernel_22736/3897200060.py", line 6
#     # print(line, end='')
#                          ^
# IndentationError: expected an indented block

# %%
df = open('trips.txt', "r")
df
# Out:
# <_io.TextIOWrapper name='trips.txt' mode='r' encoding='cp1252'>

# %%
for line in df:
    print(line)
# Out:
# block_1_trip_2_service_1,route_2,service_1,Kopiec KoÅ›ciuszki,"",1,block_1,shape_2805,
#
# block_1_trip_3_service_1,route_1,service_1,Salwator,"",1,block_1,shape_2800,
#
# block_1_trip_4_service_1,route_1,service_1,Kopiec KoÅ›ciuszki,"",0,block_1,shape_2799,
#
# block_1_trip_5_service_1,route_2,service_1,Os. Podwawelskie,"",0,block_1,shape_2802,
#
# block_1_trip_6_service_1,route_2,service_1,Kopiec KoÅ›ciuszki,"",1,block_1,shape_2803,
#
# block_1_trip_7_service_1,route_1,service_1,Salwator,"",1,block_1,shape_2800,
#
# block_1_trip_8_service_1,route_1,service_1,Kopiec KoÅ›ciuszki,"",0,block_1,shape_2799,
#
# block_1_trip_9_service_1,route_2,service_1,Os. Podwawelskie,"",0,block_1,shape_2802,
#
# block_1_trip_10_service_1,route_2,service_1,Kopiec KoÅ›ciuszki,"",1,block_1,shape_2803,
#
# block_1_trip_11_service_1,route_1,service_1,Salwator,"",1,block_1,shape_2800,
#
# block_1_trip_12_service_1,route_1,service_1,Kopiec KoÅ›ciuszki,"",0,block_1,shape_2799,
#
# ...

# %%
df = pd.read_csv('trips.txt', sep=',')
df
# Out:
#                             trip_id   route_id service_id  \
# 0          block_1_trip_2_service_1    route_2  service_1
# 1          block_1_trip_3_service_1    route_1  service_1
# 2          block_1_trip_4_service_1    route_1  service_1
# 3          block_1_trip_5_service_1    route_2  service_1
# 4          block_1_trip_6_service_1    route_2  service_1
# ...                             ...        ...        ...
# 36502  block_1744_trip_12_service_4  route_117  service_4
# 36503  block_1744_trip_13_service_4  route_117  service_4
# 36504  block_1744_trip_14_service_4  route_117  service_4
# 36505  block_1744_trip_15_service_4  route_117  service_4
# 36506  block_1744_trip_16_service_4  route_117  service_4
#
#                   trip_headsign  trip_short_name  direction_id    block_id  \
# 0             Kopiec Kościuszki              NaN             1     block_1
# 1                      Salwator              NaN             1     block_1
# ...
